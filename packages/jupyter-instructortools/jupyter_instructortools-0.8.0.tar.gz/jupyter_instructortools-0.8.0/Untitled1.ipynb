# %% [markdown]
# <div style = "height: 100%; width:10px;float:left; border-width:5px; border-color:red;border-style:solid; border-right-style:none;margin-right: 4px; min-height: 15px;"></div>
#
# ### You must initialize the software each time you use this notebook.
#  1. First, check that the notebook is "Trusted" by looking near the right of the Jupyter toolbars. If the notebook is not trusted you need to click on the "not trusted" button and trust the notebook. **You should only trust notebooks that come from a *trusted source*, such as the class website.**
#  2. The cell immediately below contains code that loads the software modules necessary for this notebook to run.  **You must run this cell each time you open the notebook or later cellsmay not work.**
#  3. If you are doing calculations that depend upon using variables passed from calculations done the previous time the notebook was opened, you will need to run those previous cells to redefine the variables.

# %%
# Cell to collapse code 
# Second line that will disappear on collapse.

# %% [markdown]
# <div style = "height: 100%; width:10px;float:left; border-width:5px; border-color:cyan;border-style:solid; border-right-style:none;margin-right: 4px; min-height: 15px;"></div>
#
# ### Steps to create a PDF file to turn in.
# To convert this notebook to a lab report to turn in you need to hide the majority of the instruction and informational cells and make a .pdf document.
# 1. Your instructor has already chosen the cells they want hidden. To hide them select "Hide Cells" from the JPSL Tools menu.
# 2. To make a pdf you must use the Browser's print capabilities. In most user interfaces this option is hidden in the little collapsed menu at the upper right of the browser window. On a macintosh it can be found in the file menu. Select "Print".
# 	* Set the destination to "Save to PDF".
# 	* Set the format to "Landscape" to accommodate the cell width.
# 	* Adjust the scale so that the whole width appears in the preview   (usually 60% - 80%).
# 	* Make sure to save the file in a   location you can find (your "Desktop" or maybe "Documents" directory).
# 	* Do Not use the options in the Jupyter "File" menu.
# 3. It is a good idea to open the created document to make sure it is OK.
# 4. When everything is OK, save this notebook one more time using "Save Notebook" in the Jupyter "File" menu and then close it using the "Close and Shutdown Notebook" option in the Jupyter "File" menu.
# 5. Turn in: the **pdf** and **ipynb** version of this notebook plus any **datafiles**.

# %% [markdown]
# <div style = "width: 100%; height:10px;border-width:5px; border-color:green;border-style:solid;border-bottom-style:none;margin-bottom: 4px; min-width: 15px;background-color:beige;"></div>
#
# ![image.png](attachment:e9db0d10-fbbc-4d5c-b423-635d05d8a587.png)
#
# <div style = "width: 100%; height:10px;border-width:5px;border-color:sienna;border-style:solid;border-top-style:none;margin-top: 4px; min-width: 15px;background-color:beige;"></div>

# %% [markdown]
# ### You must initialize the software each time you use this notebook.
#  1. First, check that the notebook is "Trusted" by looking near the right of the Jupyter toolbars. If the notebook is not trusted you need to click on the "not trusted" button and trust the notebook. **You should only trust notebooks that come from a *trusted source*, such as the class website.**
#  2. The cell immediately below contains code that loads the software modules necessary for this notebook to run. **You must run this cell each time you open the notebook or later cells may not work.**
#  3. If you are doing calculations that depend upon using variables passed from calculations done the previous time the notebook was opened, you will need to run those previous cells to redefine the variables. You can run each cell individually in order, or use the 'Restart the kernel and run all cells' button (usually represented by double fast-forward arrows).

# %%
# If no data table appears in the output of this cell, run the cell to display the table.

from IPython.display import HTML
display(HTML('<div class="jp-input_table"><div class = "jp-input_table_actions"><p class = "jp-input_table_actions">Actions only work if jupyter-datainputtable extension installed.</p><div class = "jp-input_table_actions_label" style = "display:inline-flex;">Table Actions</div><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="EditDataTable:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720034951395"}\'title="Start editing the data.">Edit Data</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="DataToPandas:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720034951395"}\'title="Create a Panda DataFrame from table.">Data to Pandas...</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="SaveDataTable:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720034951395"}\'title="Save the updated data table.">Save Table</button></div><table class="jp-input_table" id="it_1720034951395" style = "min-width:80%;"><caption class="jp-input_table" style="font-weight:bold;font-size:1.5em;color:darkkhaki;text-align:left;">Table 1: Using the Instructor Tools menu...</caption><tbody> <tr class="jp-input_table r0">  <th class="jp-input_table r0 c0" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"></th><th class="jp-input_table r0 c1" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><span class="jp-input_table_table_label">Col_0</span></th> </tr> <tr class="jp-input_table r1"><th class="jp-input_table r1 c0" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><span class="jp-input_table_table_label">0</span></th>  <td class="jp-input_table r1 c1" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><span class="jp-input_table_data_cell"></span></td> </tr></tbody></table></div>'))
# Out:
# <div class="jp-input_table"><div class = "jp-input_table_actions"><p class = "jp-input_table_actions">Actions only work if jupyter-datainputtable extension installed.</p><div class = "jp-input_table_actions_label" style = "display:inline-flex;">Table Actions</div><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="EditDataTable:jupyter-inputtable" data-commandlinker-args='{"tableID":"it_1720034951395"}'title="Start editing the data.">Edit Data</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="DataToPandas:jupyter-inputtable" data-commandlinker-args='{"tableID":"it_1720034951395"}'title="Create a Panda DataFrame from table.">Data to Pandas...</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="SaveDataTable:jupyter-i
# ...

# %% [markdown]
# Menu item works with only the pip install of jupyter-datainputtable.

# %%
from IPython.display import HTML, Markdown
stringwithlatex = '$x^y$ is a power expression'
display(HTML(stringwithlatex))
display(Markdown(stringwithlatex))
# Out:
# $x^y$ is a power expression
# $x^y$ is a power expression

# %%
display(stringwithlatex)
# Out:
# '$x^y$ is a power expression'

# %%
# If no data table appears in the output of this cell, run the cell to display the table.

from IPython.display import HTML
display(HTML('<div class="jp-input_table"><div class = "jp-input_table_actions"><p class = "jp-input_table_actions">Actions only work if jupyter-datainputtable extension installed.</p><div class = "jp-input_table_actions_label" style = "display:inline-flex;">Table Actions</div><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="EditDataTable:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720203906484"}\'title="Start editing the data.">Edit Data</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="DataToPandas:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720203906484"}\'title="Create a Panda DataFrame from table.">Data to Pandas...</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="SaveDataTable:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720203906484"}\'title="Save the updated data table.">Save Table</button></div><table class="jp-input_table" id="it_1720203906484" style = "min-width:80%;"><caption class="jp-input_table" style="font-weight:bold;font-size:1.5em;color:darkkhaki;text-align:left;"></caption><tbody> <tr class="jp-input_table r0">  <th class="jp-input_table r0 c0" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"></th><th class="jp-input_table r0 c1" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><span class="jp-input_table_table_label">Col_0</span></th> </tr> <tr class="jp-input_table r1"><th class="jp-input_table r1 c0" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><span class="jp-input_table_table_label">0</span></th>  <td class="jp-input_table r1 c1" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><span class="jp-input_table_data_cell"></span></td> </tr></tbody></table></div>'))
# Out:
# <div class="jp-input_table"><div class = "jp-input_table_actions"><p class = "jp-input_table_actions">Actions only work if jupyter-datainputtable extension installed.</p><div class = "jp-input_table_actions_label" style = "display:inline-flex;">Table Actions</div><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="EditDataTable:jupyter-inputtable" data-commandlinker-args='{"tableID":"it_1720203906484"}'title="Start editing the data.">Edit Data</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="DataToPandas:jupyter-inputtable" data-commandlinker-args='{"tableID":"it_1720203906484"}'title="Create a Panda DataFrame from table.">Data to Pandas...</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="SaveDataTable:jupyter-i
# ...

# %%
# If no data table appears in the output of this cell, run the cell to display the table.

from IPython.display import HTML
display(HTML('<div class="jp-input_table"><div class = "jp-input_table_actions"><p class = "jp-input_table_actions">Actions only work if jupyter-datainputtable extension installed.</p><div class = "jp-input_table_actions_label" style = "display:inline-flex;">Table Actions</div><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="EditDataTable:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720203949036"}\'title="Start editing the data.">Edit Data</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="DataToPandas:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720203949036"}\'title="Create a Panda DataFrame from table.">Data to Pandas...</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="SaveDataTable:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720203949036"}\'title="Save the updated data table.">Save Table</button></div><table class="jp-input_table" id="it_1720203949036" style = "min-width:80%;"><caption class="jp-input_table" style = "font-weight:bold;font-size:1.5em;color:darkkhaki;text-align:left;">Table caption?</caption><tbody> <tr class="jp-input_table r0">  <th class="jp-input_table r0 c0" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><button class="jp-Button jp-input_table_lock_btn" data-commandlinker-command="LockLabels:jupyter-inputtable" data-commandlinker-args=\'{"tableID":"it_1720203949036"}\'>Lock Column and Row Labels</button></th><th class="jp-input_table r0 c1" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><textarea class="jp-input_table_table_label" onblur="this.innerHTML=this.value;">Col_0</textarea></th> </tr> <tr class="jp-input_table r1"><th class="jp-input_table r1 c0" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><textarea class="jp-input_table_table_label" onblur="this.innerHTML=this.value;">0</textarea></th>  <td class="jp-input_table r1 c1" style="text-align:left;padding:0px;border-width:1px;border-style:solid;"><textarea class="jp-input_table_data_cell" onblur="this.innerHTML=this.value;"></textarea></td> </tr></tbody></table></div>'))
# Out:
# <div class="jp-input_table"><div class = "jp-input_table_actions"><p class = "jp-input_table_actions">Actions only work if jupyter-datainputtable extension installed.</p><div class = "jp-input_table_actions_label" style = "display:inline-flex;">Table Actions</div><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="EditDataTable:jupyter-inputtable" data-commandlinker-args='{"tableID":"it_1720203949036"}'title="Start editing the data.">Edit Data</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="DataToPandas:jupyter-inputtable" data-commandlinker-args='{"tableID":"it_1720203949036"}'title="Create a Panda DataFrame from table.">Data to Pandas...</button><button class ="jp-Button jp-input_table_actions_btn" style = "margin:4px;text-decoration:red line-through;" data-commandlinker-command="SaveDataTable:jupyter-i
# ...
